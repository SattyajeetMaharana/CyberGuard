# %%
# 1
#============================================================
# CyberGuard - Phishing URL Detection
# Team Member 1
# Notebook: 01_phishing_url_eda.ipynb
# Purpose: Dataset inspection and EDA
# ============================================================

from pathlib import Path
import sys

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Reproducibility
RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)

# ------------------------------------------------------------
# Project root
# ------------------------------------------------------------
PROJECT_ROOT = Path.cwd().resolve()

# If notebook is executed from the notebooks/ directory,
# move one level up to the project root.
if PROJECT_ROOT.name == "notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent

DATA_PATH = PROJECT_ROOT / "datasets" / "phishing" / "url" / "raw" / "phishing_url.csv"

print("Project root:")
print(PROJECT_ROOT)

print("\nDataset path:")
print(DATA_PATH)

print("\nDataset exists:", DATA_PATH.exists())
